# %% [markdown]
# # Agenda
#
# 1. Fundamentals
# 2. Data types
#     - Numbers
#     - Strings
#     - Loops
#     - Lists
#     - Tuples
#     - Dictionaries
#     - Sets
#     - Files
# 3. Functions
#     - Defining functions
#     - Arguments and parameters
#     - Locals vs. globals
#     - Return values
# 4. Modules
#     - `import`
#     - PyPI -- Python Package Index
#     - `pip` and `uv`
# 5. Objects
#     - Class
#     - Instance
#     - Methods
#     - Inheritance
# 6. Exceptions

# %% [markdown]
# # Two modes for cell input
#
# - Edit mode -- what I type goes into the cell. I can enter this mode with ENTER or by clicking in the cell
# - Command mode -- this gives Jupyter commands. I can get into command mode by clicking to the left or pressing ESC.
#
# ## Commands
#
# - `c` -- copy the current cell
# - `x` -- cut the current cell
# - `v` -- paste the last copy/cut
# - `y` -- use Python
# - `m` -- use documentation in Markdown (like this)
# - `a` -- new cell above
# - `b` -- new cell below
#
# To execute the cell, I use shift+ENTER.

# %%
# this is a comment 

print('Hello, world!')
print('Hello, world!')
print('Hello, world!')
# Out:
# Hello, world!
# Hello, world!
# Hello, world!

# %%
print(2 + 3)
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %%
# REPL -- read, eval, print loop

2+3
# Out:
# 5

# %%
# Assignment with =
x = 2
y = 3

print(x+y)
# Out:
# 5

# %%
x+y
# Out:
# 5

# %%
x
# Out:
# 2

# %% [markdown]
# # Assignment: Right before left

# %%
x = 10
y = 20

# %%
x = 10
y = x   # y = 10

x = 20
y
# Out:
# 10

# %% [markdown]
# # Variable names
