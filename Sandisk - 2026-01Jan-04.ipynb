# %% [markdown]
# # Agenda
#
# 1. Fundamentals
# 2. Data types
#     - Numbers
#     - Strings
#     - Loops
#     - Lists
#     - Tuples
#     - Dictionaries
#     - Sets
#     - Files
# 3. Functions
#     - Defining functions
#     - Arguments and parameters
#     - Locals vs. globals
#     - Return values
# 4. Modules
#     - `import`
#     - PyPI -- Python Package Index
#     - `pip` and `uv`
# 5. Objects
#     - Class
#     - Instance
#     - Methods
#     - Inheritance
# 6. Exceptions
